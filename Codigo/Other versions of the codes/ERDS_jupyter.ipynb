# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
#path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectD1511253StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=671600
#     Range : 0 ... 671599 =      0.000 ...  3357.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-8-bc403c30dfb3>:35: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 642 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 642 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649932
# stat_fun(H1): min=-7.574915 max=9.975751
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649932
# stat_fun(H1): min=-7.574915 max=9.975751
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649932
# stat_fun(H1): min=-7.445624 max=8.860303
# Running initial clustering
# Found 16 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649932
# stat_fun(H1): min=-7.445624 max=8.860303
# Running initial clustering
# Found 12 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649932
# stat_fun(H1): min=-6.699218 max=8.994066
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649932
# stat_fun(H1): min=-6.699218 max=8.994066
# Running initial clustering
# Found 9 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649361
# stat_fun(H1): min=-7.233907 max=9.547675
# Running initial clustering
# Found 11 clusters
# Permuting 99 times...
# <ipython-input-8-bc403c30dfb3>:127: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649361
# stat_fun(H1): min=-7.233907 max=9.547675
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649361
# stat_fun(H1): min=-6.602570 max=10.111182
# Running initial clustering
# Found 12 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649361
# stat_fun(H1): min=-6.602570 max=10.111182
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649361
# stat_fun(H1): min=-7.619865 max=9.838351
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649361
# stat_fun(H1): min=-7.619865 max=9.838351
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=667800
#     Range : 0 ... 667799 =      0.000 ...  3338.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-15-70ab4f0985a8>:32: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 636 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 636 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649614
# stat_fun(H1): min=-6.316948 max=11.189970
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-6.316948 max=11.189970
# Running initial clustering
# Found 34 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-5.532558 max=9.025166
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-5.532558 max=9.025166
# Running initial clustering
# Found 19 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-6.588064 max=12.909169
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-6.588064 max=12.909169
# Running initial clustering
# Found 22 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-5.233920 max=9.967753
# Running initial clustering
# <ipython-input-15-70ab4f0985a8>:124: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-5.233920 max=9.967753
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-4.245779 max=9.258923
# Running initial clustering
# Found 26 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-4.245779 max=9.258923
# Running initial clustering
# Found 28 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-4.773646 max=13.164971
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-4.773646 max=13.164971
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=669400
#     Range : 0 ... 669399 =      0.000 ...  3346.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-10-44da1c014d8b>:31: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 635 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 635 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649629
# stat_fun(H1): min=-14.862207 max=9.900887
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649629
# stat_fun(H1): min=-14.862207 max=9.900887
# Running initial clustering
# Found 21 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 3 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649629
# stat_fun(H1): min=-13.499746 max=11.817329
# Running initial clustering
# Found 28 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649629
# stat_fun(H1): min=-13.499746 max=11.817329
# Running initial clustering
# Found 5 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649629
# stat_fun(H1): min=-7.472193 max=11.019661
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649629
# stat_fun(H1): min=-7.472193 max=11.019661
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-13.934158 max=12.424798
# Running initial clustering
# Found 11 clusters
# Permuting 99 times...
# <ipython-input-10-44da1c014d8b>:123: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-13.934158 max=12.424798
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-6.818452 max=9.371662
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-6.818452 max=9.371662
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-7.663950 max=13.282055
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-7.663950 max=13.282055
# Running initial clustering
# Found 6 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectD1511253StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=667600
#     Range : 0 ... 667599 =      0.000 ...  3337.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-11-830b8a3a342f>:32: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 635 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 635 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649614
# stat_fun(H1): min=-8.152219 max=12.294846
# Running initial clustering
# Found 21 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-8.152219 max=12.294846
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-6.125434 max=9.425252
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-6.125434 max=9.425252
# Running initial clustering
# Found 9 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-7.349190 max=11.601621
# Running initial clustering
# Found 5 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-7.349190 max=11.601621
# Running initial clustering
# Found 12 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649752
# stat_fun(H1): min=-9.857525 max=11.174597
# <ipython-input-11-830b8a3a342f>:124: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649752
# stat_fun(H1): min=-9.857525 max=11.174597
# Running initial clustering
# Found 36 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649752
# stat_fun(H1): min=-6.180770 max=10.430045
# Running initial clustering
# Found 6 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649752
# stat_fun(H1): min=-6.180770 max=10.430045
# Running initial clustering
# Found 5 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649752
# stat_fun(H1): min=-9.011125 max=12.735744
# Running initial clustering
# Found 12 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649752
# stat_fun(H1): min=-9.011125 max=12.735744
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=664000
#     Range : 0 ... 663999 =      0.000 ...  3319.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-12-cdc931ac6a75>:32: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 635 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 635 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649629
# stat_fun(H1): min=-8.159217 max=11.735970
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649629
# stat_fun(H1): min=-8.159217 max=11.735970
# Running initial clustering
# Found 33 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649629
# stat_fun(H1): min=-7.874623 max=11.158428
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649629
# stat_fun(H1): min=-7.874623 max=11.158428
# Running initial clustering
# Found 25 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649629
# stat_fun(H1): min=-9.479745 max=11.589278
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649629
# stat_fun(H1): min=-9.479745 max=11.589278
# Running initial clustering
# Found 22 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-8.270366 max=11.760659
# Running initial clustering
# Found 26 clusters
# Permuting 99 times...
# <ipython-input-12-cdc931ac6a75>:124: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-8.270366 max=11.760659
# Running initial clustering
# Found 16 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-7.005383 max=11.466734
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-7.005383 max=11.466734
# Running initial clustering
# Found 29 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-6.574805 max=11.433260
# Running initial clustering
# Found 12 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-6.574805 max=11.433260
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectD1511253StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=689600
#     Range : 0 ... 689599 =      0.000 ...  3447.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-13-b745cb906f86>:32: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 960 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 960 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.648061
# stat_fun(H1): min=-11.626301 max=19.717771
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.648061
# stat_fun(H1): min=-11.626301 max=19.717771
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.648061
# stat_fun(H1): min=-10.307855 max=16.620365
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 3 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.648061
# stat_fun(H1): min=-10.307855 max=16.620365
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.648061
# stat_fun(H1): min=-14.460716 max=20.589963
# Running initial clustering
# Found 6 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.648061
# stat_fun(H1): min=-14.460716 max=20.589963
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.648021
# <ipython-input-13-b745cb906f86>:124: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# stat_fun(H1): min=-11.896100 max=18.980188
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.648021
# stat_fun(H1): min=-11.896100 max=18.980188
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.648021
# stat_fun(H1): min=-9.804193 max=15.833429
# Running initial clustering
# Found 17 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 3 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.648021
# stat_fun(H1): min=-9.804193 max=15.833429
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.648021
# stat_fun(H1): min=-14.934292 max=24.587884
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.648021
# stat_fun(H1): min=-14.934292 max=24.587884
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
path = '../Data/CLA/CLASubjectB1510203StLRHand.mat'
#path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=667400
#     Range : 0 ... 667399 =      0.000 ...  3336.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-2-92eacc8ad89a>:34: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 636 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 636 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649614
# stat_fun(H1): min=-9.249069 max=11.334349
# Running initial clustering
# Found 17 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-9.249069 max=11.334349
# Running initial clustering
# Found 46 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-5.734666 max=9.324198
# Running initial clustering
# Found 16 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-5.734666 max=9.324198
# Running initial clustering
# Found 33 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-7.703058 max=12.762471
# Running initial clustering
# Found 19 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-7.703058 max=12.762471
# Running initial clustering
# Found 30 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# <ipython-input-2-92eacc8ad89a>:126: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# stat_fun(H1): min=-10.349772 max=9.789531
# Running initial clustering
# Found 51 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-10.349772 max=9.789531
# Running initial clustering
# Found 46 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-6.419872 max=8.936723
# Running initial clustering
# Found 16 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-6.419872 max=8.936723
# Running initial clustering
# Found 9 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-5.704860 max=12.255488
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-5.704860 max=12.255488
# Running initial clustering
# Found 33 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
path = '../Data/CLA/CLASubjectB1510203StLRHand.mat'
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=667800
#     Range : 0 ... 667799 =      0.000 ...  3338.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-3-c6454c485da3>:34: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 636 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 636 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649614
# stat_fun(H1): min=-6.316948 max=11.189970
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-6.316948 max=11.189970
# Running initial clustering
# Found 34 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-5.532558 max=9.025166
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-5.532558 max=9.025166
# Running initial clustering
# Found 19 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-6.588064 max=12.909169
# Running initial clustering
# Found 15 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-6.588064 max=12.909169
# Running initial clustering
# Found 22 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-5.233920 max=9.967753
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
# <ipython-input-3-c6454c485da3>:126: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-5.233920 max=9.967753
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-4.245779 max=9.258923
# Running initial clustering
# Found 26 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-4.245779 max=9.258923
# Running initial clustering
# Found 28 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-4.773646 max=13.164971
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-4.773646 max=13.164971
# Running initial clustering
# Found 18 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
path = '../Data/CLA/CLASubjectB1510203StLRHand.mat'
#path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
path = '../Data/CLA/CLASubjectE1601193StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=664400
#     Range : 0 ... 664399 =      0.000 ...  3321.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-4-c4e4c0725489>:35: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 634 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 634 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649644
# stat_fun(H1): min=-8.421066 max=12.116085
# Running initial clustering
# Found 17 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649644
# stat_fun(H1): min=-8.421066 max=12.116085
# Running initial clustering
# Found 24 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649644
# stat_fun(H1): min=-7.082925 max=13.627932
# Running initial clustering
# Found 19 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649644
# stat_fun(H1): min=-7.082925 max=13.627932
# Running initial clustering
# Found 17 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649644
# stat_fun(H1): min=-6.444152 max=13.535581
# Running initial clustering
# Found 11 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649644
# stat_fun(H1): min=-6.444152 max=13.535581
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# <ipython-input-4-c4e4c0725489>:127: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# stat_fun(H1): min=-8.630343 max=13.019809
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-8.630343 max=13.019809
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-8.978560 max=12.837006
# Running initial clustering
# Found 3 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-8.978560 max=12.837006
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649736
# stat_fun(H1): min=-6.084918 max=11.867127
# Running initial clustering
# Found 2 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649736
# stat_fun(H1): min=-6.084918 max=11.867127
# Running initial clustering
# Found 11 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied

# %%
# -*- coding: utf-8 -*-
"""
In this code we will visualize the ERDS maps for determining a 
suitable frequency and time window. 
"""


import numpy as np
import matplotlib.pyplot as plt
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.viz.utils import center_cmap
import pymatreader

# load and preprocess data ####################################################
path = '../Data/CLA/CLASubjectA1601083StLRHand.mat' # best time 0.6  1.4, BW = 22-26
path = '../Data/CLA/CLASubjectC1512233StLRHand.mat' # best time 2.1  3.9
path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
path = '../Data/CLA/CLASubjectB1510203StLRHand.mat'
#path = '../Data/CLA/CLASubjectB1512153StLRHand.mat'
#path = '../Data/CLA/CLASubjectC1512163StLRHand.mat' # best time 2.1  3.9
#path = '../Data/CLA/CLASubjectC1511263StLRHand.mat'
#path = '../Data/CLA/CLASubjectE1512253StLRHand.mat'
path = '../Data/CLA/CLASubjectE1601223StLRHand.mat'
#path = '../Data/CLA/CLASubjectF1509163StLRHand.mat'
struct = pymatreader.read_mat(path, ignore_fields=['previous'], variable_names = 'o')
struct = struct['o']


chann = struct['chnames']
chann = chann[:-1] # pop th X3 channel, which is only used for the data adquisition. 
info = mne.create_info(ch_names = chann, 
                               sfreq = float(struct['sampFreq']),ch_types='eeg', montage='standard_1020', verbose=None)

data = np.array(struct['data'])
data = data[:,:-1]
data_V = data*1e-6 # mne reads units are in Volts

raw = mne.io.RawArray(data_V.transpose(),info, copy = "both")

raw = raw.set_eeg_reference('average', projection= False)

def type_pos(markers, sfreq = 200.0 ):
    """
    Just left and right positions, NO PASS marker
    """
    mark = []
    pos = []
    time = []
    desc = ['left', 'right'] # for assigning the movements--> left =1, right = 2, pass = 3
    for i in range(len(markers)-1):
        if markers[i]==0 and markers[i+1] != 0 and (markers[i+1] in [1,2]):
            
            mark.append(desc[markers[i+1]-1])
            pos.append((i+2))
            time.append((i+2)/sfreq)
        else:
           continue
    return mark, pos, time

markers =  np.array(struct['marker']).transpose()
[mark, pos, time] = type_pos(markers)

annotations = mne.Annotations(time, 3.0, mark) # this is the annotation of every class
raw.set_annotations(annotations)

events, _ = mne.events_from_annotations(raw)

picks = mne.pick_channels(raw.info["ch_names"], ["C3", "Cz", "C4"])

# epoch data ##################################################################
tmin, tmax = -1, 4  # define epochs around events (in s)
event_ids = dict(left=1, right=2)  # map event IDs to tasks

epochs = mne.Epochs(raw, events, event_ids, tmin - 0.5, tmax + 0.5,
                    picks=picks, baseline=None, preload=True)

# compute ERDS maps ###########################################################
freqs = np.arange(2, 36, 1)  # frequencies from 2-35Hz
n_cycles = freqs  # use constant t/f resolution
vmin, vmax = -1, 1.5  # set min and max ERDS values in plot
baseline = [-1, 0]  # baseline interval (in s)
cmap = center_cmap(plt.cm.jet, vmin, vmax)  # zero maps to white
kwargs = dict(n_permutations=100, step_down_p=0.05, seed=1,
              buffer_size=None)  # for cluster test

# Run TF decomposition overall epochs
tfr = tfr_multitaper(epochs, freqs=freqs, n_cycles=n_cycles,
                     use_fft=True, return_itc=False, average=False,
                     decim=2)
tfr.crop(tmin, tmax)
tfr.apply_baseline(baseline, mode="percent")
for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(1, 4, figsize=(12, 4),
                             gridspec_kw={"width_ratios": [10, 10, 10, 1]})
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch, ...], tail=-1,
                                     **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot([ch], vmin=vmin, vmax=vmax, cmap=(cmap, False),
                              axes=ax, colorbar=False, show=False, mask=mask,
                              mask_style="mask")

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if not ax.is_first_col():
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1])
    fig.suptitle("ERDS ({})".format(event))
    fig.show()
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=667000
#     Range : 0 ... 666999 =      0.000 ...  3334.995 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# <ipython-input-5-424d0f9fcb7f>:35: DeprecationWarning: Passing montage to create_info is deprecated and will be removed in 0.21, use raw.set_montage (or epochs.set_montage, etc.) instead
#   info = mne.create_info(ch_names = chann,
# Used Annotations descriptions: ['left', 'right']
# 635 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 635 events and 1201 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.649614
# stat_fun(H1): min=-8.275931 max=15.029665
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-8.275931 max=15.029665
# Running initial clustering
# Found 19 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-8.433924 max=14.953480
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-8.433924 max=14.953480
# Running initial clustering
# Found 10 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649614
# stat_fun(H1): min=-7.226943 max=14.005103
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649614
# stat_fun(H1): min=-7.226943 max=14.005103
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649752
# <ipython-input-5-424d0f9fcb7f>:127: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# stat_fun(H1): min=-11.348498 max=14.902499
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649752
# stat_fun(H1): min=-11.348498 max=14.902499
# Running initial clustering
# Found 13 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649752
# stat_fun(H1): min=-9.212229 max=15.321952
# Running initial clustering
# Found 11 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 2 additional clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649752
# stat_fun(H1): min=-9.212229 max=15.321952
# Running initial clustering
# Found 14 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
# Using a threshold of 1.649752
# stat_fun(H1): min=-9.660249 max=14.922481
# Running initial clustering
# Found 7 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# Using a threshold of -1.649752
# stat_fun(H1): min=-9.660249 max=14.922481
# Running initial clustering
# Found 8 clusters
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# Permuting 99 times...
#   0%|          |  : 0/99 [00:00<?,       ?it/s]
# Computing cluster p-values
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Done.
# No baseline correction applied
